# %%
#Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
traindf = pd.read_csv('train.csv')
testdf = pd.read_csv("test.csv")
ssdf = pd.read_csv('Sample_submission.csv')

# %%
from sklearn.preprocessing import LabelEncoder

for column in traindf.columns:
        if traindf[column].dtype == np.number:
            continue
        traindf[column] = LabelEncoder().fit_transform(traindf[column])

# %%
#Create a new column at the end of the dataframe that contains the same value 
traindf['Age_Years'] = traindf['Age']
#Remove the first column called age 
traindf = traindf.drop('Age', axis = 1)
#Show the dataframe
traindf
# Out:
#         Id  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0        0          0               0           1                 1
# 1        1          0               2           1                11
# 2        2          1               2           2                 1
# 3        3          0               2           1                23
# 4        4          0               2           1                 2
# ...    ...        ...             ...         ...               ...
# 1623  1623          1               1           1                18
# 1624  1624          1               2           2                 1
# 1625  1625          1               2           2                 8
# 1626  1626          1               2           0                12
# 1627  1627          1               2           1                17
#
#       Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 0             2               3             288                        2
# 1             3               1             778                        2
# 2             0               3             423                        2
# 3             0               1             971                        0
# 4             2               4             352                        2
# ...         ...             ...             ...                      ...
# 1623          2               3             385                        2
# 1624          0               3             423                        2
# 1625          1               1             696                        0
# 1626          2               0             890                        0
# 1627          0               3             159                        2
#
#       Gender  ...  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0          0  ...                 0                 12                      2
# 1          0  ...                 2                  7                      2
# 2          1  ...                 0                 12                      3
# 3          1  ...                 0                 18                      2
# 4          1  ...                 1                 10                      2
# ...      ...  ...               ...                ...                    ...
# 1623       1  ...                 0                  7                      2
# 1624       1  ...                 0                 12                      3
# 1625       1  ...                 0                  6                      2
# 1626       1  ...                 3                  4                      3
# 1627       1  ...                 0                  4                      3
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                 11                   7                        6
# 1                  3                   2                        1
# 2                  9                   7                        7
# 3                  7                   7                        1
# 4                 10                   7                        7
# ...              ...                 ...                      ...
# 1623               2                   2                        2
# 1624               9                   7                        7
# 1625               3                   2                        2
# 1626               2                   2                        2
# 1627               4                   3                        0
#
#       YearsWithCurrManager  CommunicationSkill  Behaviour  Age_Years
# 0                        7                   3          0         12
# 1                        1                   1          0         18
# 2                        3                   4          0         37
# 3                        7                   3          0         21
# 4                        8                   0          0         19
# ...                    ...                 ...        ...        ...
# 1623                     2                   2          0         24
# 1624                     3                   4          0         37
# 1625                     2                   4          0          7
# 1626                     0                   4          0         11
# 1627                     1                   1          0         11
#
# [1628 rows x 29 columns]

# %%
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
target = traindf['Attrition']
features = traindf.drop('Attrition', axis = 1)
#create the train/test split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.4, random_state=0)
#Create the model and train
model = RandomForestClassifier()
model.fit(X_train,y_train)
#predict the results for test
test_pred = model.predict_proba(X_test)

# %%
target
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1623    1
# 1624    1
# 1625    1
# 1626    1
# 1627    1
# Name: Attrition, Length: 1628, dtype: int32

# %%
features
# Out:
#         Id  BusinessTravel  Department  DistanceFromHome  Education  \
# 0        0               0           1                 1          2
# 1        1               2           1                11          3
# 2        2               2           2                 1          0
# 3        3               2           1                23          0
# 4        4               2           1                 2          2
# ...    ...             ...         ...               ...        ...
# 1623  1623               1           1                18          2
# 1624  1624               2           2                 1          0
# 1625  1625               2           2                 8          1
# 1626  1626               2           0                12          2
# 1627  1627               2           1                17          0
#
#       EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0                  3             288                        2       0
# 1                  1             778                        2       0
# 2                  3             423                        2       1
# 3                  1             971                        0       1
# 4                  4             352                        2       1
# ...              ...             ...                      ...     ...
# 1623               3             385                        2       1
# 1624               3             423                        2       1
# 1625               1             696                        0       1
# 1626               0             890                        0       1
# 1627               3             159                        2       1
#
#       JobInvolvement  ...  StockOptionLevel  TotalWorkingYears  \
# 0                  2  ...                 0                 12
# 1                  2  ...                 2                  7
# 2                  2  ...                 0                 12
# 3                  2  ...                 0                 18
# 4                  2  ...                 1                 10
# ...              ...  ...               ...                ...
# 1623               3  ...                 0                  7
# 1624               2  ...                 0                 12
# 1625               1  ...                 0                  6
# 1626               1  ...                 3                  4
# 1627               1  ...                 0                  4
#
#       TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# 0                         2              11                   7
# 1                         2               3                   2
# 2                         3               9                   7
# 3                         2               7                   7
# 4                         2              10                   7
# ...                     ...             ...                 ...
# 1623                      2               2                   2
# 1624                      3               9                   7
# 1625                      2               3                   2
# 1626                      3               2                   2
# 1627                      3               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager  CommunicationSkill  \
# 0                           6                     7                   3
# 1                           1                     1                   1
# 2                           7                     3                   4
# 3                           1                     7                   3
# 4                           7                     8                   0
# ...                       ...                   ...                 ...
# 1623                        2                     2                   2
# 1624                        7                     3                   4
# 1625                        2                     2                   4
# 1626                        2                     0                   4
# 1627                        0                     1                   1
#
#       Behaviour  Age_Years
# 0             0         12
# 1             0         18
# 2             0         37
# 3             0         21
# 4             0         19
# ...         ...        ...
# 1623          0         24
# 1624          0         37
# 1625          0          7
# 1626          0         11
# 1627          0         11
#
# [1628 rows x 28 columns]

# %%
test_pred
# Out:
# array([[0.03, 0.97],
#        [0.62, 0.38],
#        [0.56, 0.44],
#        ...,
#        [0.01, 0.99],
#        [0.45, 0.55],
#        [0.93, 0.07]])

# %%
prediction = model.predict_proba(testdf[features])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-a12dcb56fe7c> in <module>
# ----> 1 prediction = model.predict_proba(testdf[features])
#
# c:\users\raghav jindal\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2785         # Do we have a (boolean) DataFrame?
#    2786         if isinstance(key, DataFrame):
# -> 2787             return self.where(key)
#    2788
#    2789         # Do we have a (boolean) 1d indexer?
#
# c:\users\raghav jindal\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    8918
#    8919         other = com.apply_if_callable(other, self)
# -> 8920         return self._where(
#    8921             cond, other, inplace, axis, level, errors=errors, try_cast=try_cast
#    8922         )
#
# c:\users\raghav jindal\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in _where(self, cond, other, inplace, axis, level, errors, try_cast)
#    8677             for dt in cond.dtypes:
#    8678                 if not is_bool_dtype(dt):
# -> 8679                     raise ValueError(msg.format(dtype=dt))
#    8680
#    8681         cond = -cond if inplace else cond
#
# ValueError: Boolean array expected for the condition, not int32

# %%
testdf.mask(mask.reindex(testdf.index, testdf.columns, fill_value=False), 999)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-e489f0335da5> in <module>
# ----> 1 testdf.mask(mask.reindex(testdf.index, testdf.columns, fill_value=False), 999)
#
# NameError: name 'mask' is not defined

# %%
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(traindf[features],traindf[target])
predictions = rfc.predict(testdf[features])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-422800a80757> in <module>
#       3 from sklearn.ensemble import RandomForestClassifier
#       4 rfc = RandomForestClassifier()
# ----> 5 rfc.fit(traindf[features],traindf[target])
#       6 predictions = rfc.predict(testdf[features])
#
# c:\users\raghav jindal\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2785         # Do we have a (boolean) DataFrame?
#    2786         if isinstance(key, DataFrame):
# -> 2787             return self.where(key)
#    2788
#    2789         # Do we have a (boolean) 1d indexer?
#
# c:\users\raghav jindal\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    8918
#    8919         other = com.apply_if_callable(other, self)
# -> 8920         return self._where(
#    8921             cond, other, inplace, axis, level, errors=errors, try_cast=try_cast
#    8922         )
#
# c:\users\raghav jindal\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in _where(self, cond, other, inplace, axis, level, errors, try_cast)
#    8677             for dt in cond.dtypes:
#    8678                 if not is_bool_dtype(dt):
# -> 8679                     raise ValueError(msg.format(dtype=dt))
#    8680
#    8681         cond = -cond if inplace else cond
#
# ValueError: Boolean array expected for the condition, not int32
